# %% [markdown]
# # INTRODUCTION TO WEB SCRAPING

# %% [markdown]
# ## What is Web Scraping?
#
# Web scraping is the process of automatically extracting data from websites. It allows you to download data from web pages and extract specific information that you need. This can be a very useful technique for data analysis, research, and automation.
#
# There are several tools and libraries available for web scraping, but in this notebook, we will focus on using the **BeautifulSoup** library in Python.
#
# Real world **examples**:
#
#     - Scraping e-commerce wesites for product data
#
#     - Scraping job posting for marker research
#
#     - scraping news articles for sentiment analysis
#
#
# ## What is BeautifulSoup?
#
# BeautifulSoup is a Python library that makes it easy to scrape information from web pages. It parses the HTML or XML structure of a web page and provides a simple interface for navigating and searching the page.
#
# With BeautifulSoup, you can easily extract data from web pages, such as text, links, images, and tables. You can also use it to search for specific elements or attributes on a page, and to navigate between pages.

# %% [markdown]
# # Using Requests and Beautiful Soup for we scraping
#
# When scraping a website, the **first step** is to make an HTTP request to the website's server to retrieve the HTML content. Requests library is used to make this request, and it can handle various HTTP methods such as GET, POST, PUT, DELETE, etc.
#
# Requests is a Python library that is often used in conjunction with Beautiful Soup for web scraping. It is a popular HTTP library that allows Python developers to send HTTP/1.1 requests and handle responses easily.
#
# Once the HTML content is retrieved, Beautiful Soup can be used to parse the HTML and extract relevant data. Beautiful Soup is a Python library used for web scraping purposes to extract the data from HTML and XML files. It provides a convenient and easy-to-use interface for parsing HTML and XML documents.
#
# Therefore, requests and Beautiful Soup are often used together in web scraping projects. Requests is used to retrieve the HTML content, and Beautiful Soup is used to parse and extract data from the HTML content.

# %% [markdown]
# # Installing requests
#
# To install the Requests library in Python, you can use pip, which is the package installer for Python. Here are the steps to install the Requests library using pip:
#
# 1) Open a command prompt or terminal on your computer.
# 2) Type the following command and press Enter to ensure that pip is      up-to-date:
#
#                 > pip install --upggrade pip
#
# 3) Type the following command and press Enter to install the Requests library:
#
#                 > pip install requests
#
# After completing these steps, the Requests library should be installed on your computer, and you can start using it for your web scraping projects in Python.

# %% [markdown]
# ## AGENDA : To scrape the reviews of 'iPhone 11' on flipkart

# %% [markdown]
# **link** : https://www.flipkart.com/apple-iphone-11-black-64-gb/product-reviews/itm4e5041ba101fd?pid=MOBFWQ6BXGJCEYNY&page=< Specify page number >

# %%
# Load the necessary libraries

from bs4 import BeautifulSoup as bs #bs4 stands for Beautifulsoup4

import requests 

name_list = []
rating_list = []
review_list = []

for page in range(1,1105):
    
    url = "https://www.flipkart.com/apple-iphone-11-black-64-gb/product-reviews/itm4e5041ba101fd?pid=MOBFWQ6BXGJCEYNY&page="+str(page)
    status_code = requests.get(url)
    
    #get() sends a HTTP GET request and receive a response

    #get() returns a HTTP status code of response

    #If status code is 200 then OK 
    #If status code is 404 then page not found
    #If status code is 503 for server unavailable currently, etc
    
    if str(status_code) == "<Response [200]>":
        
        soup = bs(status_code.content,'html.parser') # soup is an object of bs 
        
        print("Started to scrape page ",page)
        
    #From inspect, click on select option (top right corner in inpect tab)
    #then click on any name of customer on page to get the name tag and it's class name
        
        
        names = soup.find_all('p',class_='_2sc7ZR _2V5EHH')
        
        # same with ratings and reviews
        
        ratings = soup.find_all('div',class_='_3LWZlK _1BLPMq')
        reviews = soup.find_all('div',class_='t-ZTKy')
        
        #find_all() will give all the content of specified tag and class
        
        for i in range(len(names)):
            name_list.append(names[i].get_text())
            if len(ratings) > i:
                rating_list.append(ratings[i].get_text())
            else:
                rating_list.append("N/A")
            if len(reviews) > i:
                review_list.append(reviews[i].get_text())
            else:
                review_list.append("N/A")
            
        print("Page ",page," scraped succesfully")
# Out:
# Started to scrape page  1
# Page  1  scraped succesfully
# Started to scrape page  2
# Page  2  scraped succesfully
# Started to scrape page  3
# Page  3  scraped succesfully
# Started to scrape page  4
# Page  4  scraped succesfully
# Started to scrape page  5
# Page  5  scraped succesfully
# Started to scrape page  6
# Page  6  scraped succesfully
# Started to scrape page  7
# Page  7  scraped succesfully
# Started to scrape page  8
# Page  8  scraped succesfully
# Started to scrape page  9
# Page  9  scraped succesfully
# Started to scrape page  10
# Page  10  scraped succesfully
# Started to scrape page  11
# Page  11  scraped succesfully
# Started to scrape page  12
# Page  12  scraped succesfully
# Started to scrape page  13
# Page  13  scraped succesfully
# Started to scrape page  14
# Page  14  scraped succesfully
# Started to scrape page  15
# Page  15  scraped succesfully
# Started to scrape page  16
# Page  16  scraped succesfully
# Started to scrape page  17
# Page  17  scraped succesfully
# Started to scrape page  18
# Page  18  scraped succesfully
# Started to scrape page  19
# Page  19  scraped succesfully
# Started to scrape page  20
# Page  20  scraped succesfully
# Started to scrape page  21
# Page  21  scraped succesfully
# Started to scrape page  22
# Page  22  scraped succesfully
# Started to scrape page  23
# Page  23  scraped succesfully
# Started to scrape page  24
# Page  24  scraped succesfully
# Started to scrape page  25
# Page  25  scraped succesfully
# Started to scrape page  26
# Page  26  scraped succesfully
# Started to scrape page  27
# Page  27  scraped succesfully
# Started to scrape page  28
# Page  28  scraped succesfully
# Started to scrape page  29
# Page  29  scraped succesfully
# Started to scrape page  30
# Page  30  scraped succesfully
# Started to scrape page  31
# Page  31  scraped succesfully
# Started to scrape page  32
# Page  32  scraped succesfully
# Started to scrape page  33
# Page  33  scraped succesfully
# Started to scrape page  34
# Page  34  scraped succesfully
# Started to scrape page  35
# Page  35  scraped succesfully
# Started to scrape page  36
# Page  36  scraped succesfully
# Started to scrape page  37
# Page  37  scraped succesfully
# Started to scrape page  38
# Page  38  scraped succesfully
# Started to scrape page  39
# Page  39  scraped succesfully
# Started to scrape page  40
# Page  40  scraped succesfully
# Started to scrape page  41
# Page  41  scraped succesfully
# Started to scrape page  42
# Page  42  scraped succesfully
# Started to scrape page  43
# Page  43  scraped succesfully
# Started to scrape page  44
# Page  44  scraped succesfully
# Started to scrape page  45
# Page  45  scraped succesfully
# Started to scrape page  46
# Page  46  scraped succesfully
# Started to scrape page  47
# Page  47  scraped succesfully
# Started to scrape page  48
# Page  48  scraped succesfully
# Started to scrape page  49
# Page  49  scraped succesfully
# Started to scrape page  50
# Page  50  scraped succesfully
# Started to scrape page  51
# Page  51  scraped succesfully
# Started to scrape page  52
# Page  52  scraped succesfully
# Started to scrape page  53
# Page  53  scraped succesfully
# Started to scrape page  54
# Page  54  scraped succesfully
# Started to scrape page  55
# Page  55  scraped succesfully
# Started to scrape page  56
# Page  56  scraped succesfully
# Started to scrape page  57
# Page  57  scraped succesfully
# Started to scrape page  58
# Page  58  scraped succesfully
# Started to scrape page  59
# Page  59  scraped succesfully
# Started to scrape page  60
# Page  60  scraped succesfully
# Started to scrape page  61
# Page  61  scraped succesfully
# Started to scrape page  62
# Page  62  scraped succesfully
# Started to scrape page  63
# Page  63  scraped succesfully
# Started to scrape page  64
# Page  64  scraped succesfully
# Started to scrape page  65
# Page  65  scraped succesfully
# Started to scrape page  66
# Page  66  scraped succesfully
# Started to scrape page  67
# Page  67  scraped succesfully
# Started to scrape page  68
# Page  68  scraped succesfully
# Started to scrape page  69
# Page  69  scraped succesfully
# Started to scrape page  70
# Page  70  scraped succesfully
# Started to scrape page  71
# Page  71  scraped succesfully
# Started to scrape page  72
# Page  72  scraped succesfully
# Started to scrape page  73
# Page  73  scraped succesfully
# Started to scrape page  74
# Page  74  scraped succesfully
# Started to scrape page  75
# Page  75  scraped succesfully
# Started to scrape page  76
# Page  76  scraped succesfully
# Started to scrape page  77
# Page  77  scraped succesfully
# Started to scrape page  78
# Page  78  scraped succesfully
# Started to scrape page  79
# Page  79  scraped succesfully
# Started to scrape page  80
# Page  80  scraped succesfully
# Started to scrape page  81
# Page  81  scraped succesfully
# Started to scrape page  82
# Page  82  scraped succesfully
# Started to scrape page  83
# Page  83  scraped succesfully
# Started to scrape page  84
# Page  84  scraped succesfully
# Started to scrape page  85
# Page  85  scraped succesfully
# Started to scrape page  86
# Page  86  scraped succesfully
# Started to scrape page  87
# Page  87  scraped succesfully
# Started to scrape page  88
# Page  88  scraped succesfully
# Started to scrape page  89
# Page  89  scraped succesfully
# Started to scrape page  90
# Page  90  scraped succesfully
# Started to scrape page  91
# Page  91  scraped succesfully
# Started to scrape page  92
# Page  92  scraped succesfully
# Started to scrape page  93
# Page  93  scraped succesfully
# Started to scrape page  94
# Page  94  scraped succesfully
# Started to scrape page  95
# Page  95  scraped succesfully
# Started to scrape page  96
# Page  96  scraped succesfully
# Started to scrape page  97
# Page  97  scraped succesfully
# Started to scrape page  98
# Page  98  scraped succesfully
# Started to scrape page  99
# Page  99  scraped succesfully
# Started to scrape page  100
# Page  100  scraped succesfully
# Started to scrape page  101
# Page  101  scraped succesfully
# Started to scrape page  102
# Page  102  scraped succesfully
# Started to scrape page  103
# Page  103  scraped succesfully
# Started to scrape page  104
# Page  104  scraped succesfully
# Started to scrape page  105
# Page  105  scraped succesfully
# Started to scrape page  106
# Page  106  scraped succesfully
# Started to scrape page  107
# Page  107  scraped succesfully
# Started to scrape page  108
# Page  108  scraped succesfully
# Started to scrape page  109
# Page  109  scraped succesfully
# Started to scrape page  110
# Page  110  scraped succesfully
# Started to scrape page  111
# Page  111  scraped succesfully
# Started to scrape page  112
# Page  112  scraped succesfully
# Started to scrape page  113
# Page  113  scraped succesfully
# Started to scrape page  114
# Page  114  scraped succesfully
# Started to scrape page  115
# Page  115  scraped succesfully
# Started to scrape page  116
# Page  116  scraped succesfully
# Started to scrape page  117
# Page  117  scraped succesfully
# Started to scrape page  118
# Page  118  scraped succesfully
# Started to scrape page  119
# Page  119  scraped succesfully
# Started to scrape page  120
# Page  120  scraped succesfully
# Started to scrape page  121
# Page  121  scraped succesfully
# Started to scrape page  122
# Page  122  scraped succesfully
# Started to scrape page  123
# Page  123  scraped succesfully
# Started to scrape page  124
# Page  124  scraped succesfully
# Started to scrape page  125
# Page  125  scraped succesfully
# Started to scrape page  126
# Page  126  scraped succesfully
# Started to scrape page  127
# Page  127  scraped succesfully
# Started to scrape page  128
# Page  128  scraped succesfully
# Started to scrape page  129
# Page  129  scraped succesfully
# Started to scrape page  130
# Page  130  scraped succesfully
# Started to scrape page  131
# Page  131  scraped succesfully
# Started to scrape page  132
# Page  132  scraped succesfully
# Started to scrape page  133
# Page  133  scraped succesfully
# Started to scrape page  134
# Page  134  scraped succesfully
# Started to scrape page  135
# Page  135  scraped succesfully
# Started to scrape page  136
# Page  136  scraped succesfully
# Started to scrape page  137
# Page  137  scraped succesfully
# Started to scrape page  138
# Page  138  scraped succesfully
# Started to scrape page  139
# Page  139  scraped succesfully
# Started to scrape page  140
# Page  140  scraped succesfully
# Started to scrape page  141
# Page  141  scraped succesfully
# Started to scrape page  142
# Page  142  scraped succesfully
# Started to scrape page  143
# Page  143  scraped succesfully
# Started to scrape page  144
# Page  144  scraped succesfully
# Started to scrape page  145
# Page  145  scraped succesfully
# Started to scrape page  146
# Page  146  scraped succesfully
# Started to scrape page  147
# Page  147  scraped succesfully
# Started to scrape page  148
# Page  148  scraped succesfully
# Started to scrape page  149
# Page  149  scraped succesfully
# Started to scrape page  150
# Page  150  scraped succesfully
# Started to scrape page  151
# Page  151  scraped succesfully
# Started to scrape page  152
# Page  152  scraped succesfully
# Started to scrape page  153
# Page  153  scraped succesfully
# Started to scrape page  154
# Page  154  scraped succesfully
# Started to scrape page  155
# Page  155  scraped succesfully
# Started to scrape page  156
# Page  156  scraped succesfully
# Started to scrape page  157
# Page  157  scraped succesfully
# Started to scrape page  158
# Page  158  scraped succesfully
# Started to scrape page  159
# Page  159  scraped succesfully
# Started to scrape page  160
# Page  160  scraped succesfully
# Started to scrape page  161
# Page  161  scraped succesfully
# Started to scrape page  162
# Page  162  scraped succesfully
# Started to scrape page  163
# Page  163  scraped succesfully
# Started to scrape page  164
# Page  164  scraped succesfully
# Started to scrape page  165
# Page  165  scraped succesfully
# Started to scrape page  166
# Page  166  scraped succesfully
# Started to scrape page  167
# Page  167  scraped succesfully
# Started to scrape page  168
# Page  168  scraped succesfully
# Started to scrape page  169
# Page  169  scraped succesfully
# Started to scrape page  170
# Page  170  scraped succesfully
# Started to scrape page  171
# Page  171  scraped succesfully
# Started to scrape page  172
# Page  172  scraped succesfully
# Started to scrape page  173
# Page  173  scraped succesfully
# Started to scrape page  174
# Page  174  scraped succesfully
# Started to scrape page  175
# Page  175  scraped succesfully
# Started to scrape page  176
# Page  176  scraped succesfully
# Started to scrape page  177
# Page  177  scraped succesfully
# Started to scrape page  178
# Page  178  scraped succesfully
# Started to scrape page  179
# Page  179  scraped succesfully
# Started to scrape page  180
# Page  180  scraped succesfully
# Started to scrape page  181
# Page  181  scraped succesfully
# Started to scrape page  182
# Page  182  scraped succesfully
# Started to scrape page  183
# Page  183  scraped succesfully
# Started to scrape page  184
# Page  184  scraped succesfully
# Started to scrape page  185
# Page  185  scraped succesfully
# Started to scrape page  186
# Page  186  scraped succesfully
# Started to scrape page  187
# Page  187  scraped succesfully
# Started to scrape page  188
# Page  188  scraped succesfully
# Started to scrape page  189
# Page  189  scraped succesfully
# Started to scrape page  190
# Page  190  scraped succesfully
# Started to scrape page  191
# Page  191  scraped succesfully
# Started to scrape page  192
# Page  192  scraped succesfully
# Started to scrape page  193
# Page  193  scraped succesfully
# Started to scrape page  194
# Page  194  scraped succesfully
# Started to scrape page  195
# Page  195  scraped succesfully
# Started to scrape page  196
# Page  196  scraped succesfully
# Started to scrape page  197
# Page  197  scraped succesfully
# Started to scrape page  198
# Page  198  scraped succesfully
# Started to scrape page  199
# Page  199  scraped succesfully
# Started to scrape page  200
# Page  200  scraped succesfully
# Started to scrape page  201
# Page  201  scraped succesfully
# Started to scrape page  202
# Page  202  scraped succesfully
# Started to scrape page  203
# Page  203  scraped succesfully
# Started to scrape page  204
# Page  204  scraped succesfully
# Started to scrape page  205
# Page  205  scraped succesfully
# Started to scrape page  206
# Page  206  scraped succesfully
# Started to scrape page  207
# Page  207  scraped succesfully
# Started to scrape page  208
# Page  208  scraped succesfully
# Started to scrape page  209
# Page  209  scraped succesfully
# Started to scrape page  210
# Page  210  scraped succesfully
# Started to scrape page  211
# Page  211  scraped succesfully
# Started to scrape page  212
# Page  212  scraped succesfully
# Started to scrape page  213
# Page  213  scraped succesfully
# Started to scrape page  214
# Page  214  scraped succesfully
# Started to scrape page  215
# Page  215  scraped succesfully
# Started to scrape page  216
# Page  216  scraped succesfully
# Started to scrape page  217
# Page  217  scraped succesfully
# Started to scrape page  218
# Page  218  scraped succesfully
# Started to scrape page  219
# Page  219  scraped succesfully
# Started to scrape page  220
# Page  220  scraped succesfully
# Started to scrape page  221
# Page  221  scraped succesfully
# Started to scrape page  222
# Page  222  scraped succesfully
# Started to scrape page  223
# Page  223  scraped succesfully
# Started to scrape page  224
# Page  224  scraped succesfully
# Started to scrape page  225
# Page  225  scraped succesfully
# Started to scrape page  226
# Page  226  scraped succesfully
# Started to scrape page  227
# Page  227  scraped succesfully
# Started to scrape page  228
# Page  228  scraped succesfully
# Started to scrape page  229
# Page  229  scraped succesfully
# Started to scrape page  230
# Page  230  scraped succesfully
# Started to scrape page  231
# Page  231  scraped succesfully
# Started to scrape page  232
# Page  232  scraped succesfully
# Started to scrape page  233
# Page  233  scraped succesfully
# Started to scrape page  234
# Page  234  scraped succesfully
# Started to scrape page  235
# Page  235  scraped succesfully
# Started to scrape page  236
# Page  236  scraped succesfully
# Started to scrape page  237
# Page  237  scraped succesfully
# Started to scrape page  238
# Page  238  scraped succesfully
# Started to scrape page  239
# Page  239  scraped succesfully
# Started to scrape page  240
# Page  240  scraped succesfully
# Started to scrape page  241
# Page  241  scraped succesfully
# Started to scrape page  242
# Page  242  scraped succesfully
# Started to scrape page  243
# Page  243  scraped succesfully
# Started to scrape page  244
# Page  244  scraped succesfully
# Started to scrape page  245
# Page  245  scraped succesfully
# Started to scrape page  246
# Page  246  scraped succesfully
# Started to scrape page  247
# Page  247  scraped succesfully
# Started to scrape page  248
# Page  248  scraped succesfully
# Started to scrape page  249
# Page  249  scraped succesfully
# Started to scrape page  250
# Page  250  scraped succesfully
# Started to scrape page  251
# Page  251  scraped succesfully
# Started to scrape page  252
# Page  252  scraped succesfully
# Started to scrape page  253
# Page  253  scraped succesfully
# Started to scrape page  254
# Page  254  scraped succesfully
# Started to scrape page  255
# Page  255  scraped succesfully
# Started to scrape page  256
# Page  256  scraped succesfully
# Started to scrape page  257
# Page  257  scraped succesfully
# Started to scrape page  258
# Page  258  scraped succesfully
# Started to scrape page  259
# Page  259  scraped succesfully
# Started to scrape page  260
# Page  260  scraped succesfully
# Started to scrape page  261
# Page  261  scraped succesfully
# Started to scrape page  262
# Page  262  scraped succesfully
# Started to scrape page  263
# Page  263  scraped succesfully
# Started to scrape page  264
# Page  264  scraped succesfully
# Started to scrape page  265
# Page  265  scraped succesfully
# Started to scrape page  266
# Page  266  scraped succesfully
# Started to scrape page  267
# Page  267  scraped succesfully
# Started to scrape page  268
# Page  268  scraped succesfully
# Started to scrape page  269
# Page  269  scraped succesfully
# Started to scrape page  270
# Page  270  scraped succesfully
# Started to scrape page  271
# Page  271  scraped succesfully
# Started to scrape page  272
# Page  272  scraped succesfully
# Started to scrape page  273
# Page  273  scraped succesfully
# Started to scrape page  274
# Page  274  scraped succesfully
# Started to scrape page  275
# Page  275  scraped succesfully
# Started to scrape page  276
# Page  276  scraped succesfully
# Started to scrape page  277
# Page  277  scraped succesfully
# Started to scrape page  278
# Page  278  scraped succesfully
# Started to scrape page  279
# Page  279  scraped succesfully
# Started to scrape page  280
# Page  280  scraped succesfully
# Started to scrape page  281
# Page  281  scraped succesfully
# Started to scrape page  282
# Page  282  scraped succesfully
# Started to scrape page  283
# Page  283  scraped succesfully
# Started to scrape page  284
# Page  284  scraped succesfully
# Started to scrape page  285
# Page  285  scraped succesfully
# Started to scrape page  286
# Page  286  scraped succesfully
# Started to scrape page  287
# Page  287  scraped succesfully
# Started to scrape page  288
# Page  288  scraped succesfully
# Started to scrape page  289
# Page  289  scraped succesfully
# Started to scrape page  290
# Page  290  scraped succesfully
# Started to scrape page  291
# Page  291  scraped succesfully
# Started to scrape page  292
# Page  292  scraped succesfully
# Started to scrape page  293
# Page  293  scraped succesfully
# Started to scrape page  294
# Page  294  scraped succesfully
# Started to scrape page  295
# Page  295  scraped succesfully
# Started to scrape page  296
# Page  296  scraped succesfully
# Started to scrape page  297
# Page  297  scraped succesfully
# Started to scrape page  298
# Page  298  scraped succesfully
# Started to scrape page  299
# Page  299  scraped succesfully
# Started to scrape page  300
# Page  300  scraped succesfully
# Started to scrape page  301
# Page  301  scraped succesfully
# Started to scrape page  302
# Page  302  scraped succesfully
# Started to scrape page  303
# Page  303  scraped succesfully
# Started to scrape page  304
# Page  304  scraped succesfully
# Started to scrape page  305
# Page  305  scraped succesfully
# Started to scrape page  306
# Page  306  scraped succesfully
# Started to scrape page  307
# Page  307  scraped succesfully
# Started to scrape page  308
# Page  308  scraped succesfully
# Started to scrape page  309
# Page  309  scraped succesfully
# Started to scrape page  310
# Page  310  scraped succesfully
# Started to scrape page  311
# Page  311  scraped succesfully
# Started to scrape page  312
# Page  312  scraped succesfully
# Started to scrape page  313
# Page  313  scraped succesfully
# Started to scrape page  314
# Page  314  scraped succesfully
# Started to scrape page  315
# Page  315  scraped succesfully
# Started to scrape page  316
# Page  316  scraped succesfully
# Started to scrape page  317
# Page  317  scraped succesfully
# Started to scrape page  318
# Page  318  scraped succesfully
# Started to scrape page  319
# Page  319  scraped succesfully
# Started to scrape page  320
# Page  320  scraped succesfully
# Started to scrape page  321
# Page  321  scraped succesfully
# Started to scrape page  322
# Page  322  scraped succesfully
# Started to scrape page  323
# Page  323  scraped succesfully
# Started to scrape page  324
# Page  324  scraped succesfully
# Started to scrape page  325
# Page  325  scraped succesfully
# Started to scrape page  326
# Page  326  scraped succesfully
# Started to scrape page  327
# Page  327  scraped succesfully
# Started to scrape page  328
# Page  328  scraped succesfully
# Started to scrape page  329
# Page  329  scraped succesfully
# Started to scrape page  330
# Page  330  scraped succesfully
# Started to scrape page  331
# Page  331  scraped succesfully
# Started to scrape page  332
# Page  332  scraped succesfully
# Started to scrape page  333
# Page  333  scraped succesfully
# Started to scrape page  334
# Page  334  scraped succesfully
# Started to scrape page  335
# Page  335  scraped succesfully
# Started to scrape page  336
# Page  336  scraped succesfully
# Started to scrape page  337
# Page  337  scraped succesfully
# Started to scrape page  338
# Page  338  scraped succesfully
# Started to scrape page  339
# Page  339  scraped succesfully
# Started to scrape page  340
# Page  340  scraped succesfully
# Started to scrape page  341
# Page  341  scraped succesfully
# Started to scrape page  342
# Page  342  scraped succesfully
# Started to scrape page  343
# Page  343  scraped succesfully
# Started to scrape page  344
# Page  344  scraped succesfully
# Started to scrape page  345
# Page  345  scraped succesfully
# Started to scrape page  346
# Page  346  scraped succesfully
# Started to scrape page  347
# Page  347  scraped succesfully
# Started to scrape page  348
# Page  348  scraped succesfully
# Started to scrape page  349
# Page  349  scraped succesfully
# Started to scrape page  350
# Page  350  scraped succesfully
# Started to scrape page  351
# Page  351  scraped succesfully
# Started to scrape page  352
# Page  352  scraped succesfully
# Started to scrape page  353
# Page  353  scraped succesfully
# Started to scrape page  354
# Page  354  scraped succesfully
# Started to scrape page  355
# Page  355  scraped succesfully
# Started to scrape page  356
# Page  356  scraped succesfully
# Started to scrape page  357
# Page  357  scraped succesfully
# Started to scrape page  358
# Page  358  scraped succesfully
# Started to scrape page  359
# Page  359  scraped succesfully
# Started to scrape page  360
# Page  360  scraped succesfully
# Started to scrape page  361
# Page  361  scraped succesfully
# Started to scrape page  362
# Page  362  scraped succesfully
# Started to scrape page  363
# Page  363  scraped succesfully
# Started to scrape page  364
# Page  364  scraped succesfully
# Started to scrape page  365
# Page  365  scraped succesfully
# Started to scrape page  366
# Page  366  scraped succesfully
# Started to scrape page  367
# Page  367  scraped succesfully
# Started to scrape page  368
# Page  368  scraped succesfully
# Started to scrape page  369
# Page  369  scraped succesfully
# Started to scrape page  370
# Page  370  scraped succesfully
# Started to scrape page  371
# Page  371  scraped succesfully
# Started to scrape page  372
# Page  372  scraped succesfully
# Started to scrape page  373
# Page  373  scraped succesfully
# Started to scrape page  374
# Page  374  scraped succesfully
# Started to scrape page  375
# Page  375  scraped succesfully
# Started to scrape page  376
# Page  376  scraped succesfully
# Started to scrape page  377
# Page  377  scraped succesfully
# Started to scrape page  378
# Page  378  scraped succesfully
# Started to scrape page  379
# Page  379  scraped succesfully
# Started to scrape page  380
# Page  380  scraped succesfully
# Started to scrape page  381
# Page  381  scraped succesfully
# Started to scrape page  382
# Page  382  scraped succesfully
# Started to scrape page  383
# Page  383  scraped succesfully
# Started to scrape page  384
# Page  384  scraped succesfully
# Started to scrape page  385
# Page  385  scraped succesfully
# Started to scrape page  386
# Page  386  scraped succesfully
# Started to scrape page  387
# Page  387  scraped succesfully
# Started to scrape page  388
# Page  388  scraped succesfully
# Started to scrape page  389
# Page  389  scraped succesfully
# Started to scrape page  390
# Page  390  scraped succesfully
# Started to scrape page  391
# Page  391  scraped succesfully
# Started to scrape page  392
# Page  392  scraped succesfully
# Started to scrape page  393
# Page  393  scraped succesfully
# Started to scrape page  394
# Page  394  scraped succesfully
# Started to scrape page  395
# Page  395  scraped succesfully
# Started to scrape page  396
# Page  396  scraped succesfully
# Started to scrape page  397
# Page  397  scraped succesfully
# Started to scrape page  398
# Page  398  scraped succesfully
# Started to scrape page  399
# Page  399  scraped succesfully
# Started to scrape page  400
# Page  400  scraped succesfully
# Started to scrape page  401
# Page  401  scraped succesfully
# Started to scrape page  402
# Page  402  scraped succesfully
# Started to scrape page  403
# Page  403  scraped succesfully
# Started to scrape page  404
# Page  404  scraped succesfully
# Started to scrape page  405
# Page  405  scraped succesfully
# Started to scrape page  406
# Page  406  scraped succesfully
# Started to scrape page  407
# Page  407  scraped succesfully
# Started to scrape page  408
# Page  408  scraped succesfully
# Started to scrape page  409
# Page  409  scraped succesfully
# Started to scrape page  410
# Page  410  scraped succesfully
# Started to scrape page  411
# Page  411  scraped succesfully
# Started to scrape page  412
# Page  412  scraped succesfully
# Started to scrape page  413
# Page  413  scraped succesfully
# Started to scrape page  414
# Page  414  scraped succesfully
# Started to scrape page  415
# Page  415  scraped succesfully
# Started to scrape page  416
# Page  416  scraped succesfully
# Started to scrape page  417
# Page  417  scraped succesfully
# Started to scrape page  418
# Page  418  scraped succesfully
# Started to scrape page  419
# Page  419  scraped succesfully
# Started to scrape page  420
# Page  420  scraped succesfully
# Started to scrape page  421
# Page  421  scraped succesfully
# Started to scrape page  422
# Page  422  scraped succesfully
# Started to scrape page  423
# Page  423  scraped succesfully
# Started to scrape page  424
# Page  424  scraped succesfully
# Started to scrape page  425
# Page  425  scraped succesfully
# Started to scrape page  426
# Page  426  scraped succesfully
# Started to scrape page  427
# Page  427  scraped succesfully
# Started to scrape page  428
# Page  428  scraped succesfully
# Started to scrape page  429
# Page  429  scraped succesfully
# Started to scrape page  430
# Page  430  scraped succesfully
# Started to scrape page  431
# Page  431  scraped succesfully
# Started to scrape page  432
# Page  432  scraped succesfully
# Started to scrape page  433
# Page  433  scraped succesfully
# Started to scrape page  434
# Page  434  scraped succesfully
# Started to scrape page  435
# Page  435  scraped succesfully
# Started to scrape page  436
# Page  436  scraped succesfully
# Started to scrape page  437
# Page  437  scraped succesfully
# Started to scrape page  438
# Page  438  scraped succesfully
# Started to scrape page  439
# Page  439  scraped succesfully
# Started to scrape page  440
# Page  440  scraped succesfully
# Started to scrape page  441
# Page  441  scraped succesfully
# Started to scrape page  442
# Page  442  scraped succesfully
# Started to scrape page  443
# Page  443  scraped succesfully
# Started to scrape page  444
# Page  444  scraped succesfully
# Started to scrape page  445
# Page  445  scraped succesfully
# Started to scrape page  446
# Page  446  scraped succesfully
# Started to scrape page  447
# Page  447  scraped succesfully
# Started to scrape page  448
# Page  448  scraped succesfully
# Started to scrape page  449
# Page  449  scraped succesfully
# Started to scrape page  450
# Page  450  scraped succesfully
# Started to scrape page  451
# Page  451  scraped succesfully
# Started to scrape page  452
# Page  452  scraped succesfully
# Started to scrape page  453
# Page  453  scraped succesfully
# Started to scrape page  454
# Page  454  scraped succesfully
# Started to scrape page  455
# Page  455  scraped succesfully
# Started to scrape page  456
# Page  456  scraped succesfully
# Started to scrape page  457
# Page  457  scraped succesfully
# Started to scrape page  458
# Page  458  scraped succesfully
# Started to scrape page  459
# Page  459  scraped succesfully
# Started to scrape page  460
# Page  460  scraped succesfully
# Started to scrape page  461
# Page  461  scraped succesfully
# Started to scrape page  462
# Page  462  scraped succesfully
# Started to scrape page  463
# Page  463  scraped succesfully
# Started to scrape page  464
# Page  464  scraped succesfully
# Started to scrape page  465
# Page  465  scraped succesfully
# Started to scrape page  466
# Page  466  scraped succesfully
# Started to scrape page  467
# Page  467  scraped succesfully
# Started to scrape page  468
# Page  468  scraped succesfully
# Started to scrape page  469
# Page  469  scraped succesfully
# Started to scrape page  470
# Page  470  scraped succesfully
# Started to scrape page  471
# Page  471  scraped succesfully
# Started to scrape page  472
# Page  472  scraped succesfully
# Started to scrape page  473
# Page  473  scraped succesfully
# Started to scrape page  474
# Page  474  scraped succesfully
# Started to scrape page  475
# Page  475  scraped succesfully
# Started to scrape page  476
# Page  476  scraped succesfully
# Started to scrape page  477
# Page  477  scraped succesfully
# Started to scrape page  478
# Page  478  scraped succesfully
# Started to scrape page  479
# Page  479  scraped succesfully
# Started to scrape page  480
# Page  480  scraped succesfully
# Started to scrape page  481
# Page  481  scraped succesfully
# Started to scrape page  482
# Page  482  scraped succesfully
# Started to scrape page  483
# Page  483  scraped succesfully
# Started to scrape page  484
# Page  484  scraped succesfully
# Started to scrape page  485
# Page  485  scraped succesfully
# Started to scrape page  486
# Page  486  scraped succesfully
# Started to scrape page  487
# Page  487  scraped succesfully
# Started to scrape page  488
# Page  488  scraped succesfully
# Started to scrape page  489
# Page  489  scraped succesfully
# Started to scrape page  490
# Page  490  scraped succesfully
# Started to scrape page  491
# Page  491  scraped succesfully
# Started to scrape page  492
# Page  492  scraped succesfully
# Started to scrape page  493
# Page  493  scraped succesfully
# Started to scrape page  494
# Page  494  scraped succesfully
# Started to scrape page  495
# Page  495  scraped succesfully
# Started to scrape page  496
# Page  496  scraped succesfully
# Started to scrape page  497
# Page  497  scraped succesfully
# Started to scrape page  498
# Page  498  scraped succesfully
# Started to scrape page  499
# Page  499  scraped succesfully
# Started to scrape page  500
# Page  500  scraped succesfully
# Started to scrape page  501
# Page  501  scraped succesfully
# Started to scrape page  502
# Page  502  scraped succesfully
# Started to scrape page  503
# Page  503  scraped succesfully
# Started to scrape page  504
# Page  504  scraped succesfully
# Started to scrape page  505
# Page  505  scraped succesfully
# Started to scrape page  506
# Page  506  scraped succesfully
# Started to scrape page  507
# Page  507  scraped succesfully
# Started to scrape page  508
# Page  508  scraped succesfully
# Started to scrape page  509
# Page  509  scraped succesfully
# Started to scrape page  510
# Page  510  scraped succesfully
# Started to scrape page  511
# Page  511  scraped succesfully
# Started to scrape page  512
# Page  512  scraped succesfully
# Started to scrape page  513
# Page  513  scraped succesfully
# Started to scrape page  514
# Page  514  scraped succesfully
# Started to scrape page  515
# Page  515  scraped succesfully
# Started to scrape page  516
# Page  516  scraped succesfully
# Started to scrape page  517
# Page  517  scraped succesfully
# Started to scrape page  518
# Page  518  scraped succesfully
# Started to scrape page  519
# Page  519  scraped succesfully
# Started to scrape page  520
# Page  520  scraped succesfully
# Started to scrape page  521
# Page  521  scraped succesfully
# Started to scrape page  522
# Page  522  scraped succesfully
# Started to scrape page  523
# Page  523  scraped succesfully
# Started to scrape page  524
# Page  524  scraped succesfully
# Started to scrape page  525
# Page  525  scraped succesfully
# Started to scrape page  526
# Page  526  scraped succesfully
# Started to scrape page  527
# Page  527  scraped succesfully
# Started to scrape page  528
# Page  528  scraped succesfully
# Started to scrape page  529
# Page  529  scraped succesfully
# Started to scrape page  530
# Page  530  scraped succesfully
# Started to scrape page  531
# Page  531  scraped succesfully
# Started to scrape page  532
# Page  532  scraped succesfully
# Started to scrape page  533
# Page  533  scraped succesfully
# Started to scrape page  534
# Page  534  scraped succesfully
# Started to scrape page  535
# Page  535  scraped succesfully
# Started to scrape page  536
# Page  536  scraped succesfully
# Started to scrape page  537
# Page  537  scraped succesfully
# Started to scrape page  538
# Page  538  scraped succesfully
# Started to scrape page  539
# Page  539  scraped succesfully
# Started to scrape page  540
# Page  540  scraped succesfully
# Started to scrape page  541
# Page  541  scraped succesfully
# Started to scrape page  542
# Page  542  scraped succesfully
# Started to scrape page  543
# Page  543  scraped succesfully
# Started to scrape page  544
# Page  544  scraped succesfully
# Started to scrape page  545
# Page  545  scraped succesfully
# Started to scrape page  546
# Page  546  scraped succesfully
# Started to scrape page  547
# Page  547  scraped succesfully
# Started to scrape page  548
# Page  548  scraped succesfully
# Started to scrape page  549
# Page  549  scraped succesfully
# Started to scrape page  550
# Page  550  scraped succesfully
# Started to scrape page  551
# Page  551  scraped succesfully
# Started to scrape page  552
# Page  552  scraped succesfully
# Started to scrape page  553
# Page  553  scraped succesfully
# Started to scrape page  554
# Page  554  scraped succesfully
# Started to scrape page  555
# Page  555  scraped succesfully
# Started to scrape page  556
# Page  556  scraped succesfully
# Started to scrape page  557
# Page  557  scraped succesfully
# Started to scrape page  558
# Page  558  scraped succesfully
# Started to scrape page  559
# Page  559  scraped succesfully
# Started to scrape page  560
# Page  560  scraped succesfully
# Started to scrape page  561
# Page  561  scraped succesfully
# Started to scrape page  562
# Page  562  scraped succesfully
# Started to scrape page  563
# Page  563  scraped succesfully
# Started to scrape page  564
# Page  564  scraped succesfully
# Started to scrape page  565
# Page  565  scraped succesfully
# Started to scrape page  566
# Page  566  scraped succesfully
# Started to scrape page  567
# Page  567  scraped succesfully
# Started to scrape page  568
# Page  568  scraped succesfully
# Started to scrape page  569
# Page  569  scraped succesfully
# Started to scrape page  570
# Page  570  scraped succesfully
# Started to scrape page  571
# Page  571  scraped succesfully
# Started to scrape page  572
# Page  572  scraped succesfully
# Started to scrape page  573
# Page  573  scraped succesfully
# Started to scrape page  574
# Page  574  scraped succesfully
# Started to scrape page  575
# Page  575  scraped succesfully
# Started to scrape page  576
# Page  576  scraped succesfully
# Started to scrape page  577
# Page  577  scraped succesfully
# Started to scrape page  578
# Page  578  scraped succesfully
# Started to scrape page  579
# Page  579  scraped succesfully
# Started to scrape page  580
# Page  580  scraped succesfully
# Started to scrape page  581
# Page  581  scraped succesfully
# Started to scrape page  582
# Page  582  scraped succesfully
# Started to scrape page  583
# Page  583  scraped succesfully
# Started to scrape page  584
# Page  584  scraped succesfully
# Started to scrape page  585
# Page  585  scraped succesfully
# Started to scrape page  586
# Page  586  scraped succesfully
# Started to scrape page  587
# Page  587  scraped succesfully
# Started to scrape page  588
# Page  588  scraped succesfully
# Started to scrape page  589
# Page  589  scraped succesfully
# Started to scrape page  590
# Page  590  scraped succesfully
# Started to scrape page  591
# Page  591  scraped succesfully
# Started to scrape page  592
# Page  592  scraped succesfully
# Started to scrape page  593
# Page  593  scraped succesfully
# Started to scrape page  594
# Page  594  scraped succesfully
# Started to scrape page  595
# Page  595  scraped succesfully
# Started to scrape page  596
# Page  596  scraped succesfully
# Started to scrape page  597
# Page  597  scraped succesfully
# Started to scrape page  598
# Page  598  scraped succesfully
# Started to scrape page  599
# Page  599  scraped succesfully
# Started to scrape page  600
# Page  600  scraped succesfully
# Started to scrape page  601
# Page  601  scraped succesfully
# Started to scrape page  602
# Page  602  scraped succesfully
# Started to scrape page  603
# Page  603  scraped succesfully
# Started to scrape page  604
# Page  604  scraped succesfully
# Started to scrape page  605
# Page  605  scraped succesfully
# Started to scrape page  606
# Page  606  scraped succesfully
# Started to scrape page  607
# Page  607  scraped succesfully
# Started to scrape page  608
# Page  608  scraped succesfully
# Started to scrape page  609
# Page  609  scraped succesfully
# Started to scrape page  610
# Page  610  scraped succesfully
# Started to scrape page  611
# Page  611  scraped succesfully
# Started to scrape page  612
# Page  612  scraped succesfully
# Started to scrape page  613
# Page  613  scraped succesfully
# Started to scrape page  614
# Page  614  scraped succesfully
# Started to scrape page  615
# Page  615  scraped succesfully
# Started to scrape page  616
# Page  616  scraped succesfully
# Started to scrape page  617
# Page  617  scraped succesfully
# Started to scrape page  618
# Page  618  scraped succesfully
# Started to scrape page  619
# Page  619  scraped succesfully
# Started to scrape page  620
# Page  620  scraped succesfully
# Started to scrape page  621
# Page  621  scraped succesfully
# Started to scrape page  622
# Page  622  scraped succesfully
# Started to scrape page  623
# Page  623  scraped succesfully
# Started to scrape page  624
# Page  624  scraped succesfully
# Started to scrape page  625
# Page  625  scraped succesfully
# Started to scrape page  626
# Page  626  scraped succesfully
# Started to scrape page  627
# Page  627  scraped succesfully
# Started to scrape page  628
# Page  628  scraped succesfully
# Started to scrape page  629
# Page  629  scraped succesfully
# Started to scrape page  630
# Page  630  scraped succesfully
# Started to scrape page  631
# Page  631  scraped succesfully
# Started to scrape page  632
# Page  632  scraped succesfully
# Started to scrape page  633
# Page  633  scraped succesfully
# Started to scrape page  634
# Page  634  scraped succesfully
# Started to scrape page  635
# Page  635  scraped succesfully
# Started to scrape page  636
# Page  636  scraped succesfully
# Started to scrape page  637
# Page  637  scraped succesfully
# Started to scrape page  638
# Page  638  scraped succesfully
# Started to scrape page  639
# Page  639  scraped succesfully
# Started to scrape page  640
# Page  640  scraped succesfully
# Started to scrape page  641
# Page  641  scraped succesfully
# Started to scrape page  642
# Page  642  scraped succesfully
# Started to scrape page  643
# Page  643  scraped succesfully
# Started to scrape page  644
# Page  644  scraped succesfully
# Started to scrape page  645
# Page  645  scraped succesfully
# Started to scrape page  646
# Page  646  scraped succesfully
# Started to scrape page  647
# Page  647  scraped succesfully
# Started to scrape page  648
# Page  648  scraped succesfully
# Started to scrape page  649
# Page  649  scraped succesfully
# Started to scrape page  650
# Page  650  scraped succesfully
# Started to scrape page  651
# Page  651  scraped succesfully
# Started to scrape page  652
# Page  652  scraped succesfully
# Started to scrape page  653
# Page  653  scraped succesfully
# Started to scrape page  654
# Page  654  scraped succesfully
# Started to scrape page  655
# Page  655  scraped succesfully
# Started to scrape page  656
# Page  656  scraped succesfully
# Started to scrape page  657
# Page  657  scraped succesfully
# Started to scrape page  658
# Page  658  scraped succesfully
# Started to scrape page  659
# Page  659  scraped succesfully
# Started to scrape page  660
# Page  660  scraped succesfully
# Started to scrape page  661
# Page  661  scraped succesfully
# Started to scrape page  662
# Page  662  scraped succesfully
# Started to scrape page  663
# Page  663  scraped succesfully
# Started to scrape page  664
# Page  664  scraped succesfully
# Started to scrape page  665
# Page  665  scraped succesfully
# Started to scrape page  666
# Page  666  scraped succesfully
# Started to scrape page  667
# Page  667  scraped succesfully
# Started to scrape page  668
# Page  668  scraped succesfully
# Started to scrape page  669
# Page  669  scraped succesfully
# Started to scrape page  670
# Page  670  scraped succesfully
# Started to scrape page  671
# Page  671  scraped succesfully
# Started to scrape page  672
# Page  672  scraped succesfully
# Started to scrape page  673
# Page  673  scraped succesfully
# Started to scrape page  674
# Page  674  scraped succesfully
# Started to scrape page  675
# Page  675  scraped succesfully
# Started to scrape page  676
# Page  676  scraped succesfully
# Started to scrape page  677
# Page  677  scraped succesfully
# Started to scrape page  678
# Page  678  scraped succesfully
# Started to scrape page  679
# Page  679  scraped succesfully
# Started to scrape page  680
# Page  680  scraped succesfully
# Started to scrape page  681
# Page  681  scraped succesfully
# Started to scrape page  682
# Page  682  scraped succesfully
# Started to scrape page  683
# Page  683  scraped succesfully
# Started to scrape page  684
# Page  684  scraped succesfully
# Started to scrape page  685
# Page  685  scraped succesfully
# Started to scrape page  686
# Page  686  scraped succesfully
# Started to scrape page  687
# Page  687  scraped succesfully
# Started to scrape page  688
# Page  688  scraped succesfully
# Started to scrape page  689
# Page  689  scraped succesfully
# Started to scrape page  690
# Page  690  scraped succesfully
# Started to scrape page  691
# Page  691  scraped succesfully
# Started to scrape page  692
# Page  692  scraped succesfully
# Started to scrape page  693
# Page  693  scraped succesfully
# Started to scrape page  694
# Page  694  scraped succesfully
# Started to scrape page  695
# Page  695  scraped succesfully
# Started to scrape page  696
# Page  696  scraped succesfully
# Started to scrape page  697
# Page  697  scraped succesfully
# Started to scrape page  698
# Page  698  scraped succesfully
# Started to scrape page  699
# Page  699  scraped succesfully
# Started to scrape page  700
# Page  700  scraped succesfully
# Started to scrape page  701
# Page  701  scraped succesfully
# Started to scrape page  702
# Page  702  scraped succesfully
# Started to scrape page  703
# Page  703  scraped succesfully
# Started to scrape page  704
# Page  704  scraped succesfully
# Started to scrape page  705
# Page  705  scraped succesfully
# Started to scrape page  706
# Page  706  scraped succesfully
# Started to scrape page  707
# Page  707  scraped succesfully
# Started to scrape page  708
# Page  708  scraped succesfully
# Started to scrape page  709
# Page  709  scraped succesfully
# Started to scrape page  710
# Page  710  scraped succesfully
# Started to scrape page  711
# Page  711  scraped succesfully
# Started to scrape page  712
# Page  712  scraped succesfully
# Started to scrape page  713
# Page  713  scraped succesfully
# Started to scrape page  714
# Page  714  scraped succesfully
# Started to scrape page  715
# Page  715  scraped succesfully
# Started to scrape page  716
# Page  716  scraped succesfully
# Started to scrape page  717
# Page  717  scraped succesfully
# Started to scrape page  718
# Page  718  scraped succesfully
# Started to scrape page  719
# Page  719  scraped succesfully
# Started to scrape page  720
# Page  720  scraped succesfully
# Started to scrape page  721
# Page  721  scraped succesfully
# Started to scrape page  722
# Page  722  scraped succesfully
# Started to scrape page  723
# Page  723  scraped succesfully
# Started to scrape page  724
# Page  724  scraped succesfully
# Started to scrape page  725
# Page  725  scraped succesfully
# Started to scrape page  726
# Page  726  scraped succesfully
# Started to scrape page  727
# Page  727  scraped succesfully
# Started to scrape page  728
# Page  728  scraped succesfully
# Started to scrape page  729
# Page  729  scraped succesfully
# Started to scrape page  730
# Page  730  scraped succesfully
# Started to scrape page  731
# Page  731  scraped succesfully
# Started to scrape page  732
# Page  732  scraped succesfully
# Started to scrape page  733
# Page  733  scraped succesfully
# Started to scrape page  734
# Page  734  scraped succesfully
# Started to scrape page  735
# Page  735  scraped succesfully
# Started to scrape page  736
# Page  736  scraped succesfully
# Started to scrape page  737
# Page  737  scraped succesfully
# Started to scrape page  738
# Page  738  scraped succesfully
# Started to scrape page  739
# Page  739  scraped succesfully
# Started to scrape page  740
# Page  740  scraped succesfully
# Started to scrape page  741
# Page  741  scraped succesfully
# Started to scrape page  742
# Page  742  scraped succesfully
# Started to scrape page  743
# Page  743  scraped succesfully
# Started to scrape page  744
# Page  744  scraped succesfully
# Started to scrape page  745
# Page  745  scraped succesfully
# Started to scrape page  746
# Page  746  scraped succesfully
# Started to scrape page  747
# Page  747  scraped succesfully
# Started to scrape page  748
# Page  748  scraped succesfully
# Started to scrape page  749
# Page  749  scraped succesfully
# Started to scrape page  750
# Page  750  scraped succesfully
# Started to scrape page  751
# Page  751  scraped succesfully
# Started to scrape page  752
# Page  752  scraped succesfully
# Started to scrape page  753
# Page  753  scraped succesfully
# Started to scrape page  754
# Page  754  scraped succesfully
# Started to scrape page  755
# Page  755  scraped succesfully
# Started to scrape page  756
# Page  756  scraped succesfully
# Started to scrape page  757
# Page  757  scraped succesfully
# Started to scrape page  758
# Page  758  scraped succesfully
# Started to scrape page  759
# Page  759  scraped succesfully
# Started to scrape page  760
# Page  760  scraped succesfully
# Started to scrape page  761
# Page  761  scraped succesfully
# Started to scrape page  762
# Page  762  scraped succesfully
# Started to scrape page  763
# Page  763  scraped succesfully
# Started to scrape page  764
# Page  764  scraped succesfully
# Started to scrape page  765
# Page  765  scraped succesfully
# Started to scrape page  766
# Page  766  scraped succesfully
# Started to scrape page  767
# Page  767  scraped succesfully
# Started to scrape page  768
# Page  768  scraped succesfully
# Started to scrape page  769
# Page  769  scraped succesfully
# Started to scrape page  770
# Page  770  scraped succesfully
# Started to scrape page  771
# Page  771  scraped succesfully
# Started to scrape page  772
# Page  772  scraped succesfully
# Started to scrape page  773
# Page  773  scraped succesfully
# Started to scrape page  774
# Page  774  scraped succesfully
# Started to scrape page  775
# Page  775  scraped succesfully
# Started to scrape page  776
# Page  776  scraped succesfully
# Started to scrape page  777
# Page  777  scraped succesfully
# Started to scrape page  778
# Page  778  scraped succesfully
# Started to scrape page  779
# Page  779  scraped succesfully
# Started to scrape page  780
# Page  780  scraped succesfully
# Started to scrape page  781
# Page  781  scraped succesfully
# Started to scrape page  782
# Page  782  scraped succesfully
# Started to scrape page  783
# Page  783  scraped succesfully
# Started to scrape page  784
# Page  784  scraped succesfully
# Started to scrape page  785
# Page  785  scraped succesfully
# Started to scrape page  786
# Page  786  scraped succesfully
# Started to scrape page  787
# Page  787  scraped succesfully
# Started to scrape page  788
# Page  788  scraped succesfully
# Started to scrape page  789
# Page  789  scraped succesfully
# Started to scrape page  790
# Page  790  scraped succesfully
# Started to scrape page  791
# Page  791  scraped succesfully
# Started to scrape page  792
# Page  792  scraped succesfully
# Started to scrape page  793
# Page  793  scraped succesfully
# Started to scrape page  794
# Page  794  scraped succesfully
# Started to scrape page  795
# Page  795  scraped succesfully
# Started to scrape page  796
# Page  796  scraped succesfully
# Started to scrape page  797
# Page  797  scraped succesfully
# Started to scrape page  798
# Page  798  scraped succesfully
# Started to scrape page  799
# Page  799  scraped succesfully
# Started to scrape page  800
# Page  800  scraped succesfully
# Started to scrape page  801
# Page  801  scraped succesfully
# Started to scrape page  802
# Page  802  scraped succesfully
# Started to scrape page  803
# Page  803  scraped succesfully
# Started to scrape page  804
# Page  804  scraped succesfully
# Started to scrape page  805
# Page  805  scraped succesfully
# Started to scrape page  806
# Page  806  scraped succesfully
# Started to scrape page  807
# Page  807  scraped succesfully
# Started to scrape page  808
# Page  808  scraped succesfully
# Started to scrape page  809
# Page  809  scraped succesfully
# Started to scrape page  810
# Page  810  scraped succesfully
# Started to scrape page  811
# Page  811  scraped succesfully
# Started to scrape page  812
# Page  812  scraped succesfully
# Started to scrape page  813
# Page  813  scraped succesfully
# Started to scrape page  814
# Page  814  scraped succesfully
# Started to scrape page  815
# Page  815  scraped succesfully
# Started to scrape page  816
# Page  816  scraped succesfully
# Started to scrape page  817
# Page  817  scraped succesfully
# ...
# Page  837  scraped succesfully
# Started to scrape page  838
# Page  838  scraped succesfully
# Started to scrape page  839
# Page  839  scraped succesfully
# Started to scrape page  840
# Page  840  scraped succesfully
# Started to scrape page  841
# Page  841  scraped succesfully
# Started to scrape page  842
# Page  842  scraped succesfully
# Started to scrape page  843
# Page  843  scraped succesfully
# Started to scrape page  844
# Page  844  scraped succesfully
# Started to scrape page  845
# Page  845  scraped succesfully
# Started to scrape page  846
# Page  846  scraped succesfully
# Started to scrape page  847
# Page  847  scraped succesfully
# Started to scrape page  848
# Page  848  scraped succesfully
# Started to scrape page  849
# Page  849  scraped succesfully
# Started to scrape page  850
# Page  850  scraped succesfully
# Started to scrape page  851
# Page  851  scraped succesfully
# Started to scrape page  852
# Page  852  scraped succesfully
# Started to scrape page  853
# Page  853  scraped succesfully
# Started to scrape page  854
# Page  854  scraped succesfully
# Started to scrape page  855
# Page  855  scraped succesfully
# Started to scrape page  856
# Page  856  scraped succesfully
# Started to scrape page  857
# Page  857  scraped succesfully
# Started to scrape page  858
# Page  858  scraped succesfully
# Started to scrape page  859
# Page  859  scraped succesfully
# Started to scrape page  860
# Page  860  scraped succesfully
# Started to scrape page  861
# Page  861  scraped succesfully
# Started to scrape page  862
# Page  862  scraped succesfully
# Started to scrape page  863
# Page  863  scraped succesfully
# Started to scrape page  864
# Page  864  scraped succesfully
# Started to scrape page  865
# Page  865  scraped succesfully
# Started to scrape page  866
# Page  866  scraped succesfully
# Started to scrape page  867
# Page  867  scraped succesfully
# Started to scrape page  868
# Page  868  scraped succesfully
# Started to scrape page  869
# Page  869  scraped succesfully
# Started to scrape page  870
# Page  870  scraped succesfully
# Started to scrape page  871
# Page  871  scraped succesfully
# Started to scrape page  872
# Page  872  scraped succesfully
# Started to scrape page  873
# Page  873  scraped succesfully
# Started to scrape page  874
# Page  874  scraped succesfully
# Started to scrape page  875
# Page  875  scraped succesfully
# Started to scrape page  876
# Page  876  scraped succesfully
# Started to scrape page  877
# Page  877  scraped succesfully
# Started to scrape page  878
# Page  878  scraped succesfully
# Started to scrape page  879
# Page  879  scraped succesfully
# Started to scrape page  880
# Page  880  scraped succesfully
# Started to scrape page  881
# Page  881  scraped succesfully
# Started to scrape page  882
# Page  882  scraped succesfully
# Started to scrape page  883
# Page  883  scraped succesfully
# Started to scrape page  884
# Page  884  scraped succesfully
# Started to scrape page  885
# Page  885  scraped succesfully
# Started to scrape page  886
# Page  886  scraped succesfully
# Started to scrape page  887
# Page  887  scraped succesfully
# Started to scrape page  888
# Page  888  scraped succesfully
# Started to scrape page  889
# Page  889  scraped succesfully
# Started to scrape page  890
# Page  890  scraped succesfully
# Started to scrape page  891
# Page  891  scraped succesfully
# Started to scrape page  892
# Page  892  scraped succesfully
# Started to scrape page  893
# Page  893  scraped succesfully
# Started to scrape page  894
# Page  894  scraped succesfully
# Started to scrape page  895
# Page  895  scraped succesfully
# Started to scrape page  896
# Page  896  scraped succesfully
# Started to scrape page  897
# Page  897  scraped succesfully
# Started to scrape page  898
# Page  898  scraped succesfully
# Started to scrape page  899
# Page  899  scraped succesfully
# Started to scrape page  900
# Page  900  scraped succesfully
# Started to scrape page  901
# Page  901  scraped succesfully
# Started to scrape page  902
# Page  902  scraped succesfully
# Started to scrape page  903
# Page  903  scraped succesfully
# Started to scrape page  904
# Page  904  scraped succesfully
# Started to scrape page  905
# Page  905  scraped succesfully
# Started to scrape page  906
# Page  906  scraped succesfully
# Started to scrape page  907
# Page  907  scraped succesfully
# Started to scrape page  908
# Page  908  scraped succesfully
# Started to scrape page  909
# Page  909  scraped succesfully
# Started to scrape page  910
# Page  910  scraped succesfully
# Started to scrape page  911
# Page  911  scraped succesfully
# Started to scrape page  912
# Page  912  scraped succesfully
# Started to scrape page  913
# Page  913  scraped succesfully
# Started to scrape page  914
# Page  914  scraped succesfully
# Started to scrape page  915
# Page  915  scraped succesfully
# Started to scrape page  916
# Page  916  scraped succesfully
# Started to scrape page  917
# Page  917  scraped succesfully
# Started to scrape page  918
# Page  918  scraped succesfully
# Started to scrape page  919
# Page  919  scraped succesfully
# Started to scrape page  920
# Page  920  scraped succesfully
# Started to scrape page  921
# Page  921  scraped succesfully
# Started to scrape page  922
# Page  922  scraped succesfully
# Started to scrape page  923
# Page  923  scraped succesfully
# Started to scrape page  924
# Page  924  scraped succesfully
# Started to scrape page  925
# Page  925  scraped succesfully
# Started to scrape page  926
# Page  926  scraped succesfully
# Started to scrape page  927
# Page  927  scraped succesfully
# Started to scrape page  928
# Page  928  scraped succesfully
# Started to scrape page  929
# Page  929  scraped succesfully
# Started to scrape page  930
# Page  930  scraped succesfully
# Started to scrape page  931
# Page  931  scraped succesfully
# Started to scrape page  932
# Page  932  scraped succesfully
# Started to scrape page  933
# Page  933  scraped succesfully
# Started to scrape page  934
# Page  934  scraped succesfully
# Started to scrape page  935
# Page  935  scraped succesfully
# Started to scrape page  936
# Page  936  scraped succesfully
# Started to scrape page  937
# Page  937  scraped succesfully
# Started to scrape page  938
# Page  938  scraped succesfully
# Started to scrape page  939
# Page  939  scraped succesfully
# Started to scrape page  940
# Page  940  scraped succesfully
# Started to scrape page  941
# Page  941  scraped succesfully
# Started to scrape page  942
# Page  942  scraped succesfully
# Started to scrape page  943
# Page  943  scraped succesfully
# Started to scrape page  944
# Page  944  scraped succesfully
# Started to scrape page  945
# Page  945  scraped succesfully
# Started to scrape page  946
# Page  946  scraped succesfully
# Started to scrape page  947
# Page  947  scraped succesfully
# Started to scrape page  948
# Page  948  scraped succesfully
# Started to scrape page  949
# Page  949  scraped succesfully
# Started to scrape page  950
# Page  950  scraped succesfully
# Started to scrape page  951
# Page  951  scraped succesfully
# Started to scrape page  952
# Page  952  scraped succesfully
# Started to scrape page  953
# Page  953  scraped succesfully
# Started to scrape page  954
# Page  954  scraped succesfully
# Started to scrape page  955
# Page  955  scraped succesfully
# Started to scrape page  956
# Page  956  scraped succesfully
# Started to scrape page  957
# Page  957  scraped succesfully
# Started to scrape page  958
# Page  958  scraped succesfully
# Started to scrape page  959
# Page  959  scraped succesfully
# Started to scrape page  960
# Page  960  scraped succesfully
# Started to scrape page  961
# Page  961  scraped succesfully
# Started to scrape page  962
# Page  962  scraped succesfully
# Started to scrape page  963
# Page  963  scraped succesfully
# Started to scrape page  964
# Page  964  scraped succesfully
# Started to scrape page  965
# Page  965  scraped succesfully
# Started to scrape page  966
# Page  966  scraped succesfully
# Started to scrape page  967
# Page  967  scraped succesfully
# Started to scrape page  968
# Page  968  scraped succesfully
# Started to scrape page  969
# Page  969  scraped succesfully
# Started to scrape page  970
# Page  970  scraped succesfully
# Started to scrape page  971
# Page  971  scraped succesfully
# Started to scrape page  972
# Page  972  scraped succesfully
# Started to scrape page  973
# Page  973  scraped succesfully
# Started to scrape page  974
# Page  974  scraped succesfully
# Started to scrape page  975
# Page  975  scraped succesfully
# Started to scrape page  976
# Page  976  scraped succesfully
# Started to scrape page  977
# Page  977  scraped succesfully
# Started to scrape page  978
# Page  978  scraped succesfully
# Started to scrape page  979
# Page  979  scraped succesfully
# Started to scrape page  980
# Page  980  scraped succesfully
# Started to scrape page  981
# Page  981  scraped succesfully
# Started to scrape page  982
# Page  982  scraped succesfully
# Started to scrape page  983
# Page  983  scraped succesfully
# Started to scrape page  984
# Page  984  scraped succesfully
# Started to scrape page  985
# Page  985  scraped succesfully
# Started to scrape page  986
# Page  986  scraped succesfully
# Started to scrape page  987
# Page  987  scraped succesfully
# Started to scrape page  988
# Page  988  scraped succesfully
# Started to scrape page  989
# Page  989  scraped succesfully
# Started to scrape page  990
# Page  990  scraped succesfully
# Started to scrape page  991
# Page  991  scraped succesfully
# Started to scrape page  992
# Page  992  scraped succesfully
# Started to scrape page  993
# Page  993  scraped succesfully
# Started to scrape page  994
# Page  994  scraped succesfully
# Started to scrape page  995
# Page  995  scraped succesfully
# Started to scrape page  996
# Page  996  scraped succesfully
# Started to scrape page  997
# Page  997  scraped succesfully
# Started to scrape page  998
# Page  998  scraped succesfully
# Started to scrape page  999
# Page  999  scraped succesfully
# Started to scrape page  1000
# Page  1000  scraped succesfully
# Started to scrape page  1001
# Page  1001  scraped succesfully
# Started to scrape page  1002
# Page  1002  scraped succesfully
# Started to scrape page  1003
# Page  1003  scraped succesfully
# Started to scrape page  1004
# Page  1004  scraped succesfully
# Started to scrape page  1005
# Page  1005  scraped succesfully
# Started to scrape page  1006
# Page  1006  scraped succesfully
# Started to scrape page  1007
# Page  1007  scraped succesfully
# Started to scrape page  1008
# Page  1008  scraped succesfully
# Started to scrape page  1009
# Page  1009  scraped succesfully
# Started to scrape page  1010
# Page  1010  scraped succesfully
# Started to scrape page  1011
# Page  1011  scraped succesfully
# Started to scrape page  1012
# Page  1012  scraped succesfully
# Started to scrape page  1013
# Page  1013  scraped succesfully
# Started to scrape page  1014
# Page  1014  scraped succesfully
# Started to scrape page  1015
# Page  1015  scraped succesfully
# Started to scrape page  1016
# Page  1016  scraped succesfully
# Started to scrape page  1017
# Page  1017  scraped succesfully
# Started to scrape page  1018
# Page  1018  scraped succesfully
# Started to scrape page  1019
# Page  1019  scraped succesfully
# Started to scrape page  1020
# Page  1020  scraped succesfully
# Started to scrape page  1021
# Page  1021  scraped succesfully
# Started to scrape page  1022
# Page  1022  scraped succesfully
# Started to scrape page  1023
# Page  1023  scraped succesfully
# Started to scrape page  1024
# Page  1024  scraped succesfully
# Started to scrape page  1025
# Page  1025  scraped succesfully
# Started to scrape page  1026
# Page  1026  scraped succesfully
# Started to scrape page  1027
# Page  1027  scraped succesfully
# Started to scrape page  1028
# Page  1028  scraped succesfully
# Started to scrape page  1029
# Page  1029  scraped succesfully
# Started to scrape page  1030
# Page  1030  scraped succesfully
# Started to scrape page  1031
# Page  1031  scraped succesfully
# Started to scrape page  1032
# Page  1032  scraped succesfully
# Started to scrape page  1033
# Page  1033  scraped succesfully
# Started to scrape page  1034
# Page  1034  scraped succesfully
# Started to scrape page  1035
# Page  1035  scraped succesfully
# Started to scrape page  1036
# Page  1036  scraped succesfully
# Started to scrape page  1037
# Page  1037  scraped succesfully
# Started to scrape page  1038
# Page  1038  scraped succesfully
# Started to scrape page  1039
# Page  1039  scraped succesfully
# Started to scrape page  1040
# Page  1040  scraped succesfully
# Started to scrape page  1041
# Page  1041  scraped succesfully
# Started to scrape page  1042
# Page  1042  scraped succesfully
# Started to scrape page  1043
# Page  1043  scraped succesfully
# Started to scrape page  1044
# Page  1044  scraped succesfully
# Started to scrape page  1045
# Page  1045  scraped succesfully
# Started to scrape page  1046
# Page  1046  scraped succesfully
# Started to scrape page  1047
# Page  1047  scraped succesfully
# Started to scrape page  1048
# Page  1048  scraped succesfully
# Started to scrape page  1049
# Page  1049  scraped succesfully
# Started to scrape page  1050
# Page  1050  scraped succesfully
# Started to scrape page  1051
# Page  1051  scraped succesfully
# Started to scrape page  1052
# Page  1052  scraped succesfully
# Started to scrape page  1053
# Page  1053  scraped succesfully
# Started to scrape page  1054
# Page  1054  scraped succesfully
# Started to scrape page  1055
# Page  1055  scraped succesfully
# Started to scrape page  1056
# Page  1056  scraped succesfully
# Started to scrape page  1057
# Page  1057  scraped succesfully
# Started to scrape page  1058
# Page  1058  scraped succesfully
# Started to scrape page  1059
# Page  1059  scraped succesfully
# Started to scrape page  1060
# Page  1060  scraped succesfully
# Started to scrape page  1061
# Page  1061  scraped succesfully
# Started to scrape page  1062
# Page  1062  scraped succesfully
# Started to scrape page  1063
# Page  1063  scraped succesfully
# Started to scrape page  1064
# Page  1064  scraped succesfully
# Started to scrape page  1065
# Page  1065  scraped succesfully
# Started to scrape page  1066
# Page  1066  scraped succesfully
# Started to scrape page  1067
# Page  1067  scraped succesfully
# Started to scrape page  1068
# Page  1068  scraped succesfully
# Started to scrape page  1069
# Page  1069  scraped succesfully
# Started to scrape page  1070
# Page  1070  scraped succesfully
# Started to scrape page  1071
# Page  1071  scraped succesfully
# Started to scrape page  1072
# Page  1072  scraped succesfully
# Started to scrape page  1073
# Page  1073  scraped succesfully
# Started to scrape page  1074
# Page  1074  scraped succesfully
# Started to scrape page  1075
# Page  1075  scraped succesfully
# Started to scrape page  1076
# Page  1076  scraped succesfully
# Started to scrape page  1077
# Page  1077  scraped succesfully
# Started to scrape page  1078
# Page  1078  scraped succesfully
# Started to scrape page  1079
# Page  1079  scraped succesfully
# Started to scrape page  1080
# Page  1080  scraped succesfully
# Started to scrape page  1081
# Page  1081  scraped succesfully
# Started to scrape page  1082
# Page  1082  scraped succesfully
# Started to scrape page  1083
# Page  1083  scraped succesfully
# Started to scrape page  1084
# Page  1084  scraped succesfully
# Started to scrape page  1085
# Page  1085  scraped succesfully
# Started to scrape page  1086
# Page  1086  scraped succesfully
# Started to scrape page  1087
# Page  1087  scraped succesfully
# Started to scrape page  1088
# Page  1088  scraped succesfully
# Started to scrape page  1089
# Page  1089  scraped succesfully
# Started to scrape page  1090
# Page  1090  scraped succesfully
# Started to scrape page  1091
# Page  1091  scraped succesfully
# Started to scrape page  1092
# Page  1092  scraped succesfully
# Started to scrape page  1093
# Page  1093  scraped succesfully
# Started to scrape page  1094
# Page  1094  scraped succesfully
# Started to scrape page  1095
# Page  1095  scraped succesfully
# Started to scrape page  1096
# Page  1096  scraped succesfully
# Started to scrape page  1097
# Page  1097  scraped succesfully
# Started to scrape page  1098
# Page  1098  scraped succesfully
# Started to scrape page  1099
# Page  1099  scraped succesfully
# Started to scrape page  1100
# Page  1100  scraped succesfully
# Started to scrape page  1101
# Page  1101  scraped succesfully
# Started to scrape page  1102
# Page  1102  scraped succesfully
# Started to scrape page  1103
# Page  1103  scraped succesfully
# Started to scrape page  1104
# Page  1104  scraped succesfully

# %%
# now we'll import pandas to convert the data into a csv
import pandas as pd 

df = pd.DataFrame()

df['Customer names'] = name_list
df['Ratings out of 5'] = rating_list
df['Review'] = review_list
df
# Out:
#           Customer names Ratings out of 5  \
# 0      Flipkart Customer                5
# 1      Flipkart Customer                5
# 2     Manish Raghuvanshi                5
# 3          George Haokip                4
# 4           Jimly  Gogoi                5
# ...                  ...              ...
# 9962          Rajat Garg                4
# 9963       Amarjit Singh                5
# 9964            Subham S                4
# 9965            Rohan Sk                5
# 9966       Rosy  Chettri                5
#
#                                                  Review
# 0     Really satisfied with the Product I received.....
# 1     Amazing phone with great cameras and better ba...
# 2     Great iPhone very snappy experience as apple k...
# 3     I'm Really happy with the productDelivery was ...
# 4     It's my first time to use iOS phone and I am l...
# ...                                                 ...
# 9962                                      GoodREAD MORE
# 9963                                   AwesomeREAD MORE
# 9964                          Works as usual .READ MORE
# 9965                           killer 😘😘 PhoneREAD MORE
# 9966                             awesome phoneREAD MORE
#
# [9967 rows x 3 columns]

# %%
df.to_csv(r'C:\ScrapedFiles\iPhone_11_Reviews.csv',index=False)
